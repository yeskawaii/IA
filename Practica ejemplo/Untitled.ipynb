# %%
import cv2 as cv
import numpy as np

# %%
img = cv.imread('gato_guitarra.jpg',0)
print(img.shape, img.size)
w = img.shape[0]
h = img.shape[1]
#c = img.shape[2]
#w1, h1 = img.shape
img2 = cv.imread('gato_guitarra.jpg',0)
img3 = cv.imread('gato_guitarra.jpg',0)
img4 = cv.imread('gato_guitarra.jpg',0)
img5 = cv.imread('gato_guitarra.jpg',0)
#img2 = img
for x in range(w):
    for y in range (h):
        if(img[x,y] > 50):
            img[x,y]=255
        else:
            img[x,y] = 0
#print(w, h, w1, h1)
cv.imshow('imagen',img)

for x in range(w):
    for y in range (h):
        if(img2[x,y] < 25):
            img2[x,y]=175
        elif (img2[x,y] < 50):
            img2[x,y] = 150
        elif (img2[x,y] < 100):
            img2[x,y] = 75
        elif (img2[x,y] < 150):
            img2[x,y] = 25
        elif (img2[x,y] < 200):
            img2[x,y] = 0       
        else:
            img2[x,y] = 255
#print(w, h, w1, h1)
cv.imshow('imagen2',img2)


# for x in range(w):
#     for y in range (h):
#         if(img3[x,y] < 25):
#             img3[x,y]=175
#         elif (img3[x,y] < 50):
#             img3[x,y] = 150
#         elif (img3[x,y] < 100):
#             img3[x,y] = 75
#         elif (img3[x,y] < 150):
#             img3[x,y] = 25
#         elif (img3[x,y] < 200):
#             img3[x,y] = 0       
#         else:
#             img3[x,y] = 255
# #print(w, h, w1, h1)
# cv.imshow('imagen3',img3)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# (560, 563) 315280

# %%
pwd
# Out:
# 'C:\\Users\\bono1\\InteligenciaArtificial\\Practica ejemplo'

# %%
img = cv.imread('gato_guitarra.jpg',1)
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.imshow('img',img)
cv.imshow('img2',img2)

zero = np.zeros(img.shape[:2],dtype = 'uint8')
(r,g,b) = cv.split(img)
cv.imshow('rg',r)
cv.imshow('gg',g)
cv.imshow('bb',b)

cv.imshow('rbg',cv.merge([r,b,g]))
# cv.imshow('B',cv.merge([b,zero,zero]))
# cv.imshow('G',cv.merge([zero,g,zero]))
# cv.imshow('R',cv.merge([zero,zero,r]))
# (r1,g1,b1) = cv.split(img2)
# cv.imshow('R1',cv.merge([r1,zero,zero]))
# cv.imshow('G1',cv.merge([zero,g1,zero]))
# cv.imshow('B1',cv.merge([zero,zero,b1]))

cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread('chapulin_perro.jpg',1)
#img = cv.imread('gato_guitarra.jpg',1)
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img3 =cv.cvtColor(img2, cv.COLOR_RGB2HSV)

umbralBajo=(0,80 ,80 )
umbralAlto=(10,225,255)
umbralBajoB = (170,80,80)
umbralAltoB = (180,255,255)

mascara1 = cv.inRange(img3,umbralBajo,umbralAlto)
mascara2 = cv.inRange(img3,umbralBajoB,umbralAltoB)

mascara = mascara1 + mascara2

resultado = cv.bitwise_and(img,img,mask = mascara)

cv.imshow('resultado',resultado)
cv.imshow('mascara',mascara)
cv.imshow('img',img)
cv.imshow('img2',img2)
cv.imshow('img3',img3)

cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture(0)
while True:
    ret, img = cap.read()
    img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img3 =cv.cvtColor(img2, cv.COLOR_RGB2HSV)
    
    umbralBajo=(15,80 ,80 )
    umbralAlto=(35,225,255)
    # umbralBajoB = (170,80,80)
    # umbralAltoB = (180,255,255)

    mascara = cv.inRange(img3,umbralBajo,umbralAlto)
    # mascara1 = cv.inRange(img3,umbralBajo,umbralAlto)
    # mascara2 = cv.inRange(img3,umbralBajoB,umbralAltoB)
    
    # mascara = mascara1 + mascara2
    
    resultado = cv.bitwise_and(img,img,mask = mascara)
    
    cv.imshow('resultado',resultado)
    cv.imshow('mascara',mascara)
    cv.imshow('img',img)
    # cv.imshow('img2',img2)
    # cv.imshow('img3',img3)
    
    if cv.waitKey(1) == ord('q'):
        break
cap.release()
cv.destroyAllWindows()

# %%
#buscar el color rojo y coredenadas

img = cv.imread('manzanas.jpg',1)
#img = cv.imread('gato_guitarra.jpg',1)
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img3 =cv.cvtColor(img2, cv.COLOR_RGB2HSV)

umbralBajo=(0,80 ,80 )
umbralAlto=(10,225,255)
umbralBajoB = (170,80,80)
umbralAltoB = (180,255,255)

mascara1 = cv.inRange(img3,umbralBajo,umbralAlto)
mascara2 = cv.inRange(img3,umbralBajoB,umbralAltoB)

mascara = mascara1 + mascara2

resultado = cv.bitwise_and(img,img,mask = mascara)

contornos, _ = cv.findContours(mascara,cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

for contorno in contornos:
    x, y, w, h = cv.boundingRect(contorno)
    print(f"Coordenadas: ({x}, {y}), Ancho: {w}, Alto: {h}")

cv.imshow('resultado',resultado)
cv.imshow('img3',img3)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Coordenadas: (151, 647), Ancho: 3, Alto: 1
# Coordenadas: (761, 640), Ancho: 61, Alto: 8
# Coordenadas: (155, 640), Ancho: 11, Alto: 5
# Coordenadas: (167, 637), Ancho: 2, Alto: 1
# Coordenadas: (174, 634), Ancho: 2, Alto: 1
# Coordenadas: (765, 632), Ancho: 9, Alto: 3
# Coordenadas: (688, 632), Ancho: 2, Alto: 1
# Coordenadas: (675, 622), Ancho: 5, Alto: 3
# Coordenadas: (356, 620), Ancho: 17, Alto: 5
# Coordenadas: (348, 618), Ancho: 5, Alto: 2
# Coordenadas: (346, 617), Ancho: 1, Alto: 1
# Coordenadas: (66, 616), Ancho: 4, Alto: 2
# Coordenadas: (63, 616), Ancho: 1, Alto: 1
# Coordenadas: (61, 616), Ancho: 1, Alto: 1
# Coordenadas: (340, 615), Ancho: 2, Alto: 1
# Coordenadas: (719, 613), Ancho: 7, Alto: 8
# Coordenadas: (671, 612), Ancho: 1, Alto: 1
# Coordenadas: (632, 611), Ancho: 5, Alto: 1
# Coordenadas: (555, 611), Ancho: 38, Alto: 3
# Coordenadas: (38, 611), Ancho: 4, Alto: 1
# Coordenadas: (382, 610), Ancho: 1, Alto: 2
# Coordenadas: (673, 609), Ancho: 1, Alto: 1
# Coordenadas: (655, 607), Ancho: 1, Alto: 1
# Coordenadas: (5, 606), Ancho: 1, Alto: 2
# Coordenadas: (0, 606), Ancho: 4, Alto: 2
# Coordenadas: (354, 605), Ancho: 17, Alto: 14
# Coordenadas: (9, 605), Ancho: 2, Alto: 1
# Coordenadas: (368, 604), Ancho: 3, Alto: 1
# Coordenadas: (14, 604), Ancho: 5, Alto: 3
# Coordenadas: (751, 602), Ancho: 1, Alto: 1
# Coordenadas: (743, 602), Ancho: 1, Alto: 1
# Coordenadas: (330, 600), Ancho: 1, Alto: 1
# Coordenadas: (823, 599), Ancho: 1, Alto: 1
# Coordenadas: (256, 599), Ancho: 2, Alto: 1
# Coordenadas: (799, 592), Ancho: 2, Alto: 1
# Coordenadas: (797, 592), Ancho: 1, Alto: 1
# Coordenadas: (624, 592), Ancho: 2, Alto: 1
# Coordenadas: (793, 591), Ancho: 1, Alto: 1
# Coordenadas: (637, 591), Ancho: 2, Alto: 1
# Coordenadas: (226, 588), Ancho: 1, Alto: 2
# Coordenadas: (216, 581), Ancho: 3, Alto: 3
# Coordenadas: (212, 575), Ancho: 5, Alto: 7
# Coordenadas: (584, 561), Ancho: 1, Alto: 1
# Coordenadas: (627, 555), Ancho: 3, Alto: 2
# Coordenadas: (605, 555), Ancho: 1, Alto: 1
# Coordenadas: (631, 553), Ancho: 5, Alto: 3
# Coordenadas: (607, 552), Ancho: 5, Alto: 3
# Coordenadas: (556, 548), Ancho: 2, Alto: 3
# Coordenadas: (651, 544), Ancho: 1, Alto: 1
# Coordenadas: (653, 542), Ancho: 1, Alto: 1
# Coordenadas: (590, 536), Ancho: 2, Alto: 3
# Coordenadas: (984, 533), Ancho: 14, Alto: 16
# Coordenadas: (590, 532), Ancho: 3, Alto: 3
# Coordenadas: (569, 532), Ancho: 4, Alto: 2
# Coordenadas: (781, 528), Ancho: 30, Alto: 20
# Coordenadas: (655, 521), Ancho: 6, Alto: 4
# Coordenadas: (662, 520), Ancho: 1, Alto: 1
# Coordenadas: (638, 520), Ancho: 2, Alto: 3
# Coordenadas: (129, 519), Ancho: 10, Alto: 2
# Coordenadas: (122, 519), Ancho: 2, Alto: 1
# Coordenadas: (102, 518), Ancho: 16, Alto: 1
# Coordenadas: (36, 518), Ancho: 14, Alto: 3
# Coordenadas: (664, 516), Ancho: 3, Alto: 3
# Coordenadas: (632, 509), Ancho: 5, Alto: 3
# Coordenadas: (644, 497), Ancho: 1, Alto: 4
# Coordenadas: (629, 497), Ancho: 1, Alto: 1
# Coordenadas: (632, 496), Ancho: 1, Alto: 1
# Coordenadas: (643, 493), Ancho: 2, Alto: 3
# Coordenadas: (569, 491), Ancho: 3, Alto: 1
# Coordenadas: (644, 488), Ancho: 2, Alto: 3
# Coordenadas: (577, 488), Ancho: 4, Alto: 1
# Coordenadas: (674, 478), Ancho: 1, Alto: 1
# Coordenadas: (674, 475), Ancho: 7, Alto: 3
# Coordenadas: (642, 474), Ancho: 4, Alto: 13
# Coordenadas: (636, 472), Ancho: 3, Alto: 6
# Coordenadas: (640, 464), Ancho: 2, Alto: 5
# Coordenadas: (688, 452), Ancho: 3, Alto: 5
# Coordenadas: (201, 440), Ancho: 1, Alto: 1
# Coordenadas: (688, 438), Ancho: 2, Alto: 3
# Coordenadas: (169, 414), Ancho: 1, Alto: 2
# Coordenadas: (625, 409), Ancho: 1, Alto: 2
# Coordenadas: (619, 404), Ancho: 3, Alto: 3
# Coordenadas: (614, 400), Ancho: 1, Alto: 1
# Coordenadas: (609, 396), Ancho: 1, Alto: 1
# Coordenadas: (198, 396), Ancho: 7, Alto: 8
# Coordenadas: (481, 383), Ancho: 1, Alto: 1
# Coordenadas: (184, 376), Ancho: 1, Alto: 1
# Coordenadas: (199, 375), Ancho: 2, Alto: 2
# Coordenadas: (158, 369), Ancho: 11, Alto: 44
# Coordenadas: (160, 366), Ancho: 1, Alto: 2
# Coordenadas: (478, 361), Ancho: 1, Alto: 1
# Coordenadas: (174, 344), Ancho: 7, Alto: 5
# Coordenadas: (171, 339), Ancho: 1, Alto: 1
# Coordenadas: (687, 336), Ancho: 1, Alto: 1
# Coordenadas: (715, 328), Ancho: 23, Alto: 14
# Coordenadas: (680, 327), Ancho: 1, Alto: 1
# Coordenadas: (183, 326), Ancho: 1, Alto: 1
# Coordenadas: (704, 325), Ancho: 11, Alto: 5
# Coordenadas: (709, 321), Ancho: 1, Alto: 1
# Coordenadas: (694, 320), Ancho: 4, Alto: 2
# Coordenadas: (687, 316), Ancho: 1, Alto: 1
# Coordenadas: (700, 313), Ancho: 13, Alto: 15
# Coordenadas: (663, 288), Ancho: 2, Alto: 2
# Coordenadas: (312, 264), Ancho: 2, Alto: 1
# Coordenadas: (293, 254), Ancho: 1, Alto: 1
# Coordenadas: (300, 248), Ancho: 1, Alto: 1
# Coordenadas: (532, 247), Ancho: 3, Alto: 3
# Coordenadas: (225, 247), Ancho: 7, Alto: 1
# Coordenadas: (182, 228), Ancho: 1, Alto: 1
# Coordenadas: (384, 220), Ancho: 1, Alto: 1
# Coordenadas: (640, 219), Ancho: 1, Alto: 1
# Coordenadas: (188, 218), Ancho: 4, Alto: 3
# Coordenadas: (193, 216), Ancho: 1, Alto: 1
# Coordenadas: (634, 215), Ancho: 1, Alto: 1
# Coordenadas: (417, 198), Ancho: 2, Alto: 2
# Coordenadas: (410, 198), Ancho: 2, Alto: 2
# Coordenadas: (198, 196), Ancho: 26, Alto: 16
# Coordenadas: (225, 195), Ancho: 1, Alto: 1
# Coordenadas: (465, 187), Ancho: 5, Alto: 4
# Coordenadas: (547, 175), Ancho: 1, Alto: 1
# Coordenadas: (435, 175), Ancho: 1, Alto: 1
# Coordenadas: (486, 174), Ancho: 3, Alto: 2
# Coordenadas: (457, 168), Ancho: 5, Alto: 5
# Coordenadas: (443, 168), Ancho: 7, Alto: 3
# Coordenadas: (464, 164), Ancho: 6, Alto: 4
# Coordenadas: (349, 133), Ancho: 19, Alto: 11
# Coordenadas: (256, 130), Ancho: 2, Alto: 1
# Coordenadas: (413, 128), Ancho: 1, Alto: 1
# Coordenadas: (259, 128), Ancho: 1, Alto: 1
# Coordenadas: (392, 125), Ancho: 20, Alto: 9
# Coordenadas: (351, 125), Ancho: 5, Alto: 10
# Coordenadas: (391, 119), Ancho: 1, Alto: 1
# Coordenadas: (289, 112), Ancho: 1, Alto: 1
# Coordenadas: (252, 111), Ancho: 3, Alto: 3
# Coordenadas: (359, 108), Ancho: 5, Alto: 3
# Coordenadas: (363, 97), Ancho: 19, Alto: 8
# Coordenadas: (239, 90), Ancho: 1, Alto: 1
# Coordenadas: (370, 88), Ancho: 7, Alto: 5
# Coordenadas: (72, 88), Ancho: 9, Alto: 1
# Coordenadas: (22, 84), Ancho: 10, Alto: 4
# Coordenadas: (228, 82), Ancho: 2, Alto: 3
# Coordenadas: (380, 77), Ancho: 23, Alto: 7
# Coordenadas: (14, 76), Ancho: 1, Alto: 1
# Coordenadas: (479, 73), Ancho: 53, Alto: 90
# Coordenadas: (392, 68), Ancho: 6, Alto: 2
# Coordenadas: (382, 68), Ancho: 9, Alto: 7
# Coordenadas: (413, 58), Ancho: 10, Alto: 5
# Coordenadas: (155, 56), Ancho: 932, Alto: 592
# Coordenadas: (454, 55), Ancho: 1, Alto: 1
# Coordenadas: (305, 55), Ancho: 1, Alto: 1
# Coordenadas: (199, 48), Ancho: 40, Alto: 46
# Coordenadas: (200, 45), Ancho: 8, Alto: 3
# Coordenadas: (350, 43), Ancho: 32, Alto: 25
# Coordenadas: (357, 42), Ancho: 1, Alto: 1
# Coordenadas: (20, 39), Ancho: 173, Alto: 84
# Coordenadas: (33, 38), Ancho: 3, Alto: 2
# Coordenadas: (36, 37), Ancho: 6, Alto: 3
# Coordenadas: (236, 34), Ancho: 77, Alto: 89
# Coordenadas: (63, 30), Ancho: 1, Alto: 1
# Coordenadas: (111, 29), Ancho: 1, Alto: 1
# Coordenadas: (59, 22), Ancho: 1, Alto: 2
# Coordenadas: (55, 21), Ancho: 1, Alto: 1
# Coordenadas: (189, 0), Ancho: 105, Alto: 23
# Coordenadas: (0, 0), Ancho: 178, Alto: 43
